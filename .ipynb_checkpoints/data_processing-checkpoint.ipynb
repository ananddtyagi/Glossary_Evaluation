# %%
import pandas as pd

dict1 = pd.read_csv('electricity1.csv', delimiter='|')
dict1
# Out:
#    Alternating Current (AC)  \
# 0                   Ammeter
# 1                  Ampacity
# 2          Ampere-Hour (Ah)
# 3                Ampere (A)
# 4            Apparent Power
# ..                      ...
# 74                Voltmeter
# 75           Watt-hour (Wh)
# 76                 Watt (W)
# 77                Wattmeter
# 78                 Waveform
#
#    An electric current that reverses its direction many times a second at regular intervals.
# 0   An instrument for measuring the flow of electr...
# 1   The maximum amount of electric current a condu...
# 2   A unit of measure for battery capacity. It is ...
# 3   A unit of measure for the intensity of an elec...
# 4   Measured in volt-ampers (VA). Apparent power i...
# ..                                                ...
# 74  An instrument for measuring the force in volts...
# 75  A unit of electrical energy equivalent to a po...
# 76  A unit of electrical power. One watt is equiva...
# ...
